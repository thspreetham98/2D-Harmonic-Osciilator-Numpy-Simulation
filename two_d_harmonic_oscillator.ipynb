# %%
import importlib
from IPython.display import HTML
import two_d_harmonic_oscillator
import numpy as np
from matplotlib.animation import PillowWriter

# %%
snapshots_max_mem_in_GB = 4.0

# %%
params = two_d_harmonic_oscillator.Sim_Params(
    xmax=5.0,
    res=256,
    dt=0.5,
    timesteps=10000,
    wf_offset=(-2.0, 0.0),
    V_offset=(0.0, 0.0),
    snapshots_max_mem_in_GB=snapshots_max_mem_in_GB
)

# %%
sim = two_d_harmonic_oscillator.Simulator(params)

# %%
# ani = sim.simulate()
# HTML(ani.to_jshtml())

# %%
# ani.save('2D_sim.gif', writer=PillowWriter(fps=10))

# %%
sim.simulate_without_animation()

# %%
for i in range(5):
    sim.get_eigenstates_from_snapshots(i)

# %% [markdown]
# # Smaller dt

# %%
params = two_d_harmonic_oscillator.Sim_Params(
    xmax=5.0,
    res=256,
    dt=0.1,
    timesteps=10000,
    wf_offset=(-2.0, 0.0),
    V_offset=(0.0, 0.0),
    snapshots_max_mem_in_GB=snapshots_max_mem_in_GB
)
sim = two_d_harmonic_oscillator.Simulator(params)
sim.simulate_without_animation()
for i in range(5):
    sim.get_eigenstates_from_snapshots(i)

# %% [markdown]
# # More initial offset

# %%
params = two_d_harmonic_oscillator.Sim_Params(
    xmax=5.0,
    res=256,
    dt=0.1,
    timesteps=10000,
    wf_offset=(-3.0, 0.0),
    V_offset=(0.0, 0.0),
    snapshots_max_mem_in_GB=snapshots_max_mem_in_GB
)
sim = two_d_harmonic_oscillator.Simulator(params)
sim.simulate_without_animation()
for i in range(5):
    sim.get_eigenstates_from_snapshots(i)

# %%
params = two_d_harmonic_oscillator.Sim_Params(
    xmax=5.0,
    res=256,
    dt=0.1,
    timesteps=10000,
    wf_offset=(-3.0, 0.0),
    V_offset=(0.0, 0.0),
    snapshots_max_mem_in_GB=snapshots_max_mem_in_GB
)
sim = two_d_harmonic_oscillator.Simulator(params)
sim.simulate_without_animation()
for i in range(5):
    sim.get_eigenstates_from_snapshots(i)
